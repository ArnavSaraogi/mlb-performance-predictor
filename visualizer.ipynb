# %% [markdown]
# # Stats Visualizer

# %%
import pandas as pd

# %%
df = pd.read_csv('stats_300.csv')
df.head()
# Out:
#   last_name, first_name  player_id  year  on_base_plus_slg  babip  xbadiff  \
# 0       Cabrera, Miguel     408234  2021             0.702  0.305    0.022
# 1        Molina, Yadier     425877  2021             0.667  0.283   -0.003
# 2      Cruz Jr., Nelson     443558  2021             0.831  0.286    0.001
# 3        Peralta, David     444482  2021             0.727  0.303    0.016
# 4      Escobar, Alcides     444876  2021             0.744  0.337    0.017
#
#    xslgdiff  wobadiff
# 0    -0.034    -0.010
# 1    -0.036    -0.016
# 2    -0.015    -0.017
# 3     0.057     0.021
# 4     0.042     0.016

# %%
df.plot(title = 'BABIP vs OPS, 2021 to 2024', kind = 'scatter', x = 'babip', y = 'on_base_plus_slg')
# Out:
# <Axes: title={'center': 'BABIP vs OPS, 2021 to 2024'}, xlabel='babip', ylabel='on_base_plus_slg'>

# %%
df2 = pd.read_csv('out.csv')
ax1 = (df2.plot(title = "Change in Outcome vs Luck in Prior Season", 
                kind = 'scatter', 
                x = 'wobadiff (2021)', 
                y = 'ops_change 2021-2022', 
                xlabel = 'wOBA-xwOBA',
                ylabel = 'OPS % Change'))
